# %% [markdown]
# <a href="https://colab.research.google.com/github/vmatam7/hds5210/blob/main/FINAL/Final_Project_covid_Vinay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HDS5210-2024**

# %% [markdown]
# # **Final Project**

# %% [markdown]
# 10/8/2024

# %% [markdown]
# ![covid](https://cdn.pixabay.com/photo/2020/05/15/18/46/corona-5174671_960_720.jpg)

# %% [markdown]
# In this project, I will complete an Data Analysis on three datasets chosen to analyze trends and patterns related to COVID-19 and its potential economic effects across different countries. Through the analysis process, I aim to understand the distribution, structure, and relationships between variables in each dataset. For simplicity, we will refer to the datasets as the first dataset, second dataset, and third dataset.

# %% [markdown]
# # Goal

# %% [markdown]
# The goal of this project is to examine the impact and spread of COVID-19 from 2020 to 2023, while analyzing its effects on global GDP and economic recovery.

# %% [markdown]
# # Background

# %% [markdown]
# COVID 19 is therefore an infectious disease brought about by a recently identified coronavirus.
#
# Common symptoms of the COVID-19 virus are mild to moderate respiratory symptoms, and the patient recovers without further intervention. Those over 65 years of age, with co-morbid conditions such as hypertension, diabetes, COPD and cancer, are more at risk for severe disease.
#
# The best ways of preventing and delaying its spread is to understand all you can about the COVID-19 virus, the illness it produces, and its pattern of transmission. Preventing the spread of the infection by washing your hand or using a wash hand basin containing alcohol frequently and avoid touching your face.
#
# The COVID-19 virus is spread through droplet infection with saliva or discharge from the nose, for example, when an infected person is coughing or sneezing, so you should also observe spike etiquette (for example, coughing into a bent elbow).
#
# At this, there are no specific vaccines or treatments for COVID-19. However, there are many current and planned clinical trials examining different possible treatments. WHO will post additional information on clinical results as soon as they are published.
#
# Stay informed: Watch news, know how safe is your surroundings
#
# Protect yourself: public information Myth busters Questions and answers Situations reports All information of the COVID 19 outbreak

# %% [markdown]
# # Introduction

# %% [markdown]
# The COVID-19 pandemic has had an unprecedented impact on the world, not only in terms of public health but also in its economic consequences. By examining the data, we gain a deeper understanding of how rapidly the virus spread and how severely it affected different regions. The pandemic's effects on GDP reveal a complex interplay of challenges and adaptive measures, including government stimulus, shifts in consumer behavior, and evolving industries. This project seeks to explore these dynamics, particularly focusing on how various countries, such as the UK and the US, navigated the crisis and the varying outcomes they faced.

# %% [markdown]
# **Visualizing the Impact: COVID-19 Confirmed Cases in India**
#
# As part of this exploration, we'll complement our narrative with a dynamic visual representation of COVID-19 confirmed cases in India. The bar-chart-race graph will provide a state-wise breakdown, offering insights into the varying impact of the virus across different regions.
#
# *Note: While the project is not directly related to Indian datasets, visualizing COVID-19 data from India serves as an illustrative and relatable example. As the author of this exploration, hailing from India, the decision to use India as an example adds a personal touch to the presentation, in my opinion.*

# %%
# %%HTML
# <div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/2061549" data-url="https://flo.uri.sh/visualisation/2061549/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div>
# Out:
# <div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/2061549" data-url="https://flo.uri.sh/visualisation/2061549/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div>

# %% [markdown]
# # Datasets

# %% [markdown]
# Dataset 1 comprises numbers retrieved from multiple countries on the most current scale in regards to COVID-19 as of the data gathering date, including confirmed cases, active cases, COVID-19 recovered cases, and COVID-19 death rates. It also displays new cases and changes for the last week, so it helps to see the dynamics and peculiarities of the main pandemic characteristics in different regions.
#
# Another dataset(2) is the World Bank’s dataset which contains data on the Gross Domestic Product (GDP) of different countries in recent years (2020-2023), by analyzing the economic trends cross-sectionally with COVID-19 statistics.
#
# Final dataset contains the cumulative count of confirmed, death and recovered cases of COVID-19 from different countries from 22nd January 2020

# %% [markdown]
# # Formats

# %% [markdown]
# 1. Dataset 1: "csv"
# 2. Dataset 2: "xls"
# 3. Dataset 3: "csv"

# %% [markdown]
# # Links

# %% [markdown]
# 1. Link 1: " https://www.kaggle.com/datasets/imdevskp/corona-virus-report "
#
# 2. Link 2: " https://data.worldbank.org/indicator/NY.GDP.MKTP.CD " or " https://databank.worldbank.org/source/world-development-indicators# "
#
# 3. Link 3: " https://github.com/imdevskp/covid_19_jhu_data_web_scrap_and_cleaning/blob/master/covid_19_clean_complete.csv "

# %% [markdown]
# # Import

# %% [markdown]
# Before doing any kind of Data Analysis first let's import libraries that help do  Analysis and file handling within Google Colab.

# %%
import pandas as pd
import numpy as np
from google.colab import data_table
from google.colab import files
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_table.enable_dataframe_formatter()

# %% [markdown]
# Starting with Pandas and NumPy libraries importation which allows working with structured data and performing arithmetic and statistical analysis tasks required to navigate datasets. Data tables and files make collab more interactive and it provides an option to construct and visualize a table containing data notebook and even upload a file within the notebook. For visualization we want to use Matplotlib: Matplotlib is a basic-level library to plot all kinds of tools for statistical graphics for EDA.  Together, these libraries form a functional list of tools for a broad Exploratory Data Analysis process and data visualization in Colab.
#
# The following code cell after the importation will create an interactive display format of the Pandas DataFrames. This feature converts DataFrames into scrollable and sort tables, which is more convenient for users to look at and search through data with an option for large data sets. You can make it wider or narrower by scrolling horizontally by magnifying the screen or using the daily functions from the Colab notebook.

# %% [markdown]
# # About Datasets

# %% [markdown]
# ### Dataset 1:

# %% [markdown]
# DATASET 1: Explains the trends of the most current COVID-19 data for each country.

# %% [markdown]
# we developed codes to upload a file in Google Colab, show the names and sizes of all of the uploaded files, and lastly read the file into a data frame using Pandas. It reads the data from "country_wise_latest.csv" into a pandas data frame named "mydataframe1", and then the command ".columns" is used to print the names of the columns used in the data. This arrangement guarantees the data is loaded perfectly right from the point of analysis to the conclusion we draw.

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4f3d898e-139b-4079-8057-bda5736bede0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f3d898e-139b-4079-8057-bda5736bede0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
mydataframe1 = pd.read_csv("country_wise_latest.csv")

# %%
print(mydataframe1.columns)
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# #### Columns:
#
# - **Index**: Row number or unique identifier.
# - **Country**: Name of the country or region.
# - **Confirmed**: Total confirmed COVID-19 cases.
# - **Deaths**: Total number of deaths due to COVID-19.
# - **Recovered**: Total recovered cases.
# - **Active**: Current active cases (Confirmed - Deaths - Recovered).
# - **New cases**: Newly reported cases since the last update.
# - **New deaths**: Newly reported deaths since the last update.
# - **New recovered**: Newly reported recoveries since the last update.
# - **Deaths by 100 Cases**: Death rate per 100 confirmed cases.
# - **Recovered by 100 Cases**: Recovery rate per 100 confirmed cases.
# - **Deaths by 100 Recovered**: Deaths per 100 recovered cases.
# - **Confirmed last week**: Confirmed cases reported one week prior.
# - **1 week change**: Difference in confirmed cases from last week.
# - **1 week Percentage increase**: Percentage increase in cases over the past week.
# - **WHO Region**: World Health Organization region for the country.

# %% [markdown]
# ### Dataset 2:

# %% [markdown]
# DATASET 2: Integrates the resource containing economic information to enable the examination of its economic consequences.

# %% [markdown]
# We did the same for dataset 2 so we started with uploading the xls file and next, we read the data from CSV into a pandas data frame named  "mydataframe2". Finally, we printed the columns

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-82d8303b-7fc0-434c-8be3-49c82aa87f2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82d8303b-7fc0-434c-8be3-49c82aa87f2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
mydataframe2 = pd.read_excel("GDP.xls", engine= 'xlrd')

# %%
mydataframe2.columns
# Out:
# Index(['ï»¿CountryName',    'CountryCode', 'Indicator Name', 'Indicator Code',
#                    2020,             2021,             2022,             2023],
#       dtype='object')

# %%
print(mydataframe2.columns)
# Out:
# Index(['ï»¿CountryName',    'CountryCode', 'Indicator Name', 'Indicator Code',
#                    2020,             2021,             2022,             2023],
#       dtype='object')

# %% [markdown]
# #### Columns:
#
# - **CountryName**: The name of each country.
# - **CountryCode**: A unique code assigned to each country, typically based on ISO standards.
# - **Indicator Name**: The specific metric or indicator being measured (e.g., GDP, population growth).
# - **Indicator Code**: A unique code for each indicator, allowing easy reference and sorting.
# - **2020, 2021, 2022, 2023**: Values of the specified indicator for each of these years.

# %% [markdown]
# ### Dataset 3:

# %% [markdown]
# DATASET 3: Explains the trends of the most current COVID-19 data (this is a cleaned data).

# %% [markdown]
# We did the same for dataset 3 so we started with uploading the csv file and next, we read the data from CSV into a pandas data frame named  "mydataframe3". Finally, we printed the columns

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-1bb6450c-bfef-4467-b1b4-758a2475008b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bb6450c-bfef-4467-b1b4-758a2475008b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
mydataframe3 = pd.read_csv("covid_19_clean_complete.csv")

# %%
print(mydataframe3.columns)
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %% [markdown]
# - **Province/State**: Administrative subdivision.
# - **Country/Region**: Country name.
# - **Lat**: Latitude of the location.
# - **Long**: Longitude of the location.
# - **Date**: Date of data entry.
# - **Confirmed**: Total confirmed cases.
# - **Deaths**: Total deaths recorded.
# - **Recovered**: Total recovered cases.
# - **Active**: Current active cases.
# - **WHO Region**: WHO classification for the country.

# %% [markdown]
# # Data Cleaning and Transformation

# %%
mydataframe2.isnull().sum()
# Out:
# ï»¿CountryName     0
# CountryCode        0
# Indicator Name     0
# Indicator Code     0
# 2020               9
# 2021              10
# 2022              16
# 2023              33
# dtype: int64

# %%
mydataframe3.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
mydataframe3.duplicated().sum()
# Out:
# 0

# %%
mydataframe1 = mydataframe1.drop_duplicates()

# Remove rows with null values
mydataframe1 = mydataframe1.dropna()

# Optionally, reset the index after removing rows
mydataframe1.reset_index(drop=True, inplace=True)

# %%
mydataframe2 = mydataframe2.drop_duplicates()

# Optionally, reset the index after removing rows
mydataframe2.reset_index(drop=True, inplace=True)

# %%
mydataframe3 = mydataframe3.drop_duplicates()

# Remove rows with null values
mydataframe3 = mydataframe3.dropna()

# Optionally, reset the index after removing rows
mydataframe3.reset_index(drop=True, inplace=True)

# %%
# Rename the problematic column
mydataframe2.rename(columns={mydataframe2.columns[0]: "CountryName"}, inplace=True)

# %%
# Convert all column names to strings
mydataframe2.columns = [str(col) for col in mydataframe2.columns]

# %%
mydataframe2['2020'] = mydataframe2['2020'].astype(float)
mydataframe2['2021'] = mydataframe2['2021'].astype(float)
mydataframe2['2022'] = mydataframe2['2022'].astype(float)
mydataframe2['2023'] = mydataframe2['2023'].astype(float)

# %%
# Drop the 'Indicator Name' column
mydataframe2 = mydataframe2.drop(columns=['Indicator Name'])

# %%
# Convert the 'Date' column to datetime type
mydataframe3['Date'] = pd.to_datetime(mydataframe3['Date'])

# %%
mydataframe1 = mydataframe1.rename(columns={'Country/Region': 'Country'})

# %% [markdown]
# # Statistical Analysis

# %%
mydataframe1.describe(include="all")
# Out:
#             Country     Confirmed         Deaths     Recovered        Active  \
# count           187  1.870000e+02     187.000000  1.870000e+02  1.870000e+02
# unique          187           NaN            NaN           NaN           NaN
# top     Afghanistan           NaN            NaN           NaN           NaN
# freq              1           NaN            NaN           NaN           NaN
# mean            NaN  8.813094e+04    3497.518717  5.063148e+04  3.400194e+04
# std             NaN  3.833187e+05   14100.002482  1.901882e+05  2.133262e+05
# min             NaN  1.000000e+01       0.000000  0.000000e+00  0.000000e+00
# 25%             NaN  1.114000e+03      18.500000  6.265000e+02  1.415000e+02
# 50%             NaN  5.059000e+03     108.000000  2.815000e+03  1.600000e+03
# 75%             NaN  4.046050e+04     734.000000  2.260600e+04  9.149000e+03
# max             NaN  4.290259e+06  148011.000000  1.846641e+06  2.816444e+06
#
# ...

# %% [markdown]
# #### Insights
# The dataset shows variability in COVID-19 impact across countries.
#
# - **Cases**: Confirmed cases vary widely, with an average of 88,131 but a median of only 5,059, indicating most countries have fewer cases while a few have very high counts.
# - **Deaths**: The average death count is 3,498 per country, with a death rate around 3% of confirmed cases.
# - **Recoveries**: Recoveries average 50,631, with a high recovery rate of 65% across countries.
# - **New Cases and Weekly Changes**: New cases average 1,223 daily, with weekly changes in confirmed cases showing rapid fluctuations—some countries see increases as high as 226%.

# %%
mydataframe2.describe(include="all")
# Out:
#        CountryName CountryCode  Indicator Code          2020          2021  \
# count          266         266             266  2.570000e+02  2.560000e+02
# unique         266         266               1           NaN           NaN
# top          Aruba         ABW  NY.GDP.MKTP.CD           NaN           NaN
# freq             1           1             266           NaN           NaN
# mean           NaN         NaN             NaN  2.731496e+12  3.143176e+12
# std            NaN         NaN             NaN  9.351887e+12  1.068045e+13
# min            NaN         NaN             NaN  5.174659e+07  6.019641e+07
# 25%            NaN         NaN             NaN  9.505065e+09  1.001319e+10
# 50%            NaN         NaN             NaN  5.373453e+10  6.246662e+10
# 75%            NaN         NaN             NaN  5.470000e+11  6.502500e+11
# max            NaN         NaN             NaN  8.560000e+13  9.750000e+13
#
#                 2022          2023
# ...

# %% [markdown]
# #### Insights
#
# This dataset contains **GDP (US$)** values for various countries from 2020 to 2023.
#
# - **Count**: The dataset covers GDP data for 266 countries.
# - **Mean GDP**: Ranges from ~ 2.7 trillion in 2020 to ~3.7 trillion in 2023, showing a general increase.
# - **Standard Deviation**: High variability, indicating significant GDP differences across countries.
# - **Median GDP**: Gradually rises from ~53.7 billion in 2020 to ~85.7 billion in 2023, reflecting growth across countries.
# - **Range**: GDP values range widely, from about 52 million to over $100 trillion, with wealthier economies in the upper range.

# %%
mydataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# #### Insights
#
# All datatypes in dataset 1 are correct so we do not have to convert it.

# %%
mydataframe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CountryName     266 non-null    object
#  1   CountryCode     266 non-null    object
#  2   Indicator Code  266 non-null    object
#  3   2020            257 non-null    float64
#  4   2021            256 non-null    float64
#  5   2022            250 non-null    float64
#  6   2023            233 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 14.7+ KB

# %% [markdown]
# #### Insights
#
# All datatypes in dataset 2 are correct so we do not have to convert it.

# %% [markdown]
# In our case we don't have to use astype() function

# %%
mydataframe3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14664 entries, 0 to 14663
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  14664 non-null  object
#  2   Lat             14664 non-null  float64
#  3   Long            14664 non-null  float64
#  4   Date            14664 non-null  datetime64[ns]
#  5   Confirmed       14664 non-null  int64
#  6   Deaths          14664 non-null  int64
#  7   Recovered       14664 non-null  int64
#  8   Active          14664 non-null  int64
#  9   WHO Region      14664 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Insights
#
# All datatypes in dataset 3 are correctly converted.

# %% [markdown]
# # Function

# %%
def create_barplot(data, x_col, y_col, title, xlabel, ylabel, top_n=20):
    """
    Function to create and display a bar plot.

    Parameters:
    - data: DataFrame with the relevant data.
    - x_col: Column name to be used for the x-axis (numeric values).
    - y_col: Column name to be used for the y-axis (categories).
    - title: Title for the plot.
    - xlabel: Label for the x-axis.
    - ylabel: Label for the y-axis.
    - top_n: Number of top countries to display (default is 20).
    """
    # Create a bar plot
    plt.figure(figsize=(10, 8))
    sns.barplot(data=data.sort_values(x_col, ascending=False).head(top_n)[::-1],
                x=x_col, y=y_col)
    plt.title(title, fontsize=16)
    plt.xlabel(xlabel, fontsize=12)
    plt.ylabel(ylabel, fontsize=12)
    plt.show()

# %% [markdown]
# # Analysis for Dataset 1

# %%
# https://stackoverflow.com/questions/63988743/how-to-draw-multiple-line-plots-in-a-grid
fig, xx = plt.subplots(2, 3, figsize=(25, 15))
fig.suptitle("COVID-19 EDA")

# Histograms using Matplotlib
xx[0, 0].hist(mydataframe1['Confirmed'], bins=20, color='lightblue', edgecolor='black')
xx[0, 0].set_title("Confirmed Cases Distribution")
xx[0, 0].set_xlabel("Confirmed Cases")
xx[0, 0].set_ylabel("Frequency")

xx[0, 1].hist(mydataframe1['Deaths'], bins=20, color='salmon', edgecolor='black')
xx[0, 1].set_title("Deaths Distribution")
xx[0, 1].set_xlabel("Deaths")
xx[0, 1].set_ylabel("Frequency")

xx[0, 2].hist(mydataframe1['Recovered'], bins=20, color='lightgreen', edgecolor='black')
xx[0, 2].set_title("Recovered Cases Distribution")
xx[0, 2].set_xlabel("Recovered Cases")
xx[0, 2].set_ylabel("Frequency")

# Boxplots using Matplotlib
xx[1, 0].boxplot(mydataframe1['Confirmed'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
xx[1, 0].set_title("Boxplot of Confirmed Cases")
xx[1, 0].set_xlabel("Confirmed Cases")

xx[1, 1].boxplot(mydataframe1['Deaths'], vert=False, patch_artist=True, boxprops=dict(facecolor='salmon'))
xx[1, 1].set_title("Boxplot of Deaths")
xx[1, 1].set_xlabel("Deaths")

xx[1, 2].boxplot(mydataframe1['Recovered'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
xx[1, 2].set_title("Boxplot of Recovered Cases")
xx[1, 2].set_xlabel("Recovered Cases")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# First, we started by plotting histograms of Confirmed, Deaths, and Recovered from dataset 1. The next plots generated by this code are box plots of the same columns. When we observe the distribution of confirmed cases, deaths, and recovered features we can see that most of the cases are on the lower side of the graphs but that does not mean that there are lower numbers of cases of covid infected, deaths, and recovers. The main thing we should observe is the scale when we take the scale of each graph into account then we can say an insight that there are more active confirmed cases than recoveries and deaths, more recoveries than deaths, and fewer deaths than active cases. When it comes to box plots we can say that most countries had the same level of spread of the pandemic but in some countries, it was far more this number accounted for 4 to 5 points which can be spotted in the graphs as an outlier. So overall there are more cases with lower numbers and fewer cases with higher numbers for confirmed cases, deaths, and recovered cases.

# %%
# Country with the highest confirmed cases
conm = mydataframe1.loc[mydataframe1['Confirmed'].idxmax(), ['Country', 'Confirmed']]

# Country with the highest recovered cases
recm = mydataframe1.loc[mydataframe1['Recovered'].idxmax(), ['Country', 'Recovered']]

print("Country with Highest Confirmed Cases:")
print(conm)

print("\nCountry with Highest Recovered Cases:")
print(recm)
# Out:
# Country with Highest Confirmed Cases:
# Country           US
# Confirmed    4290259
# Name: 173, dtype: object
#
# Country with Highest Recovered Cases:
# Country       Brazil
# Recovered    1846641
# Name: 23, dtype: object

# %%
# Scatter Plot for Deaths vs. Confirmed Cases
plt.figure(figsize=(10, 6))
plt.scatter(mydataframe1['Confirmed'], mydataframe1['Deaths'], color='purple', alpha=0.6, edgecolors='w', s=40)
plt.title("Deaths vs. Confirmed Cases")
plt.xlabel("Confirmed Cases")
plt.ylabel("Deaths")
plt.grid()
plt.show()

# Scatter Plot for Recovered vs. Confirmed Cases
plt.figure(figsize=(10, 6))
plt.scatter(mydataframe1['Confirmed'], mydataframe1['Recovered'], color='darkgreen', alpha=0.6, edgecolors='w', s=40)
plt.title("Recovered vs. Confirmed Cases")
plt.xlabel("Confirmed Cases")
plt.ylabel("Recovered")
plt.grid()
plt.show()

# %% [markdown]
# The first scatter plot shows a weak positive correlation between confirmed cases and deaths. This means that there is a slight upward trend, but there is a large amount of scatter in the data. We draw a conclusion that there are many confirmed cases with very few deaths.
#
# The second scatter plot shows a weak positive relation this means that there is a slight upward trend but there was also a point with more recovers and confirmed cases when compared to other points. The main thing is that many points are spread in the lower end which is almost same conclusion as previous graph but different scale.

# %%
# Maximum confirmed cases
conm = mydataframe1['Confirmed'].idxmax()

# Country name and values for confirmed and recovered
name = mydataframe1.loc[conm, 'Country']
c = mydataframe1.loc[conm, 'Confirmed']
r = mydataframe1.loc[conm, 'Recovered']

print(f"Country with the highest confirmed cases: {name}")
print(f"Confirmed Cases: {c}")
print(f"Recovered Cases: {r}")
# Out:
# Country with the highest confirmed cases: US
# Confirmed Cases: 4290259
# Recovered Cases: 1325804

# %%
# Line Plot for Confirmed Cases Last Week
plt.figure(figsize=(10, 6))
plt.plot(mydataframe1['Confirmed last week'], label='Confirmed Last Week', color='blue', marker='o')
plt.title("Confirmed Cases Last Week")
plt.xlabel("Countries (Sorted by Confirmed Last Week)")
plt.ylabel("Cases")
plt.legend()
plt.grid()
plt.show()

# %%
# Again line plot
plt.figure(figsize=(14, 8))
plt.plot(mydataframe1['1 week change'].reset_index(drop=True), label='1-Week Change', color='blue', marker='o')

# Labeling
plt.title("1-Week Change in COVID-19 Cases")
plt.xlabel("Countries (Sorted by 1-Week Change)")
plt.ylabel("Cases / Percentage")
plt.legend()

# %% [markdown]
# The first line plot shows the confirmed cases last week for various countries, sorted by the number of confirmed cases last week.  The y-axis shows the number of cases, and the x-axis shows the countries sorted by confirmed cases last week. Particularly there are 4 countries that stand out with 2000000, 1200000, 3800000, and 8000000 approx cases. Almost the same pattern was observed in the next graph. The y-axis shows the number of cases, and the x-axis shows the countries sorted by the 1-week change in cases. We observe that there are a few countries with very large increases in cases which are almost 10, and there are many countries with small increases or decreases in cases.

# %%
top_5 = mydataframe1[['Country', '1 week change']].sort_values(by='1 week change', ascending=False).head(10)
print("Top 10 Countries with the Highest 1-Week Change:")
print(top_5)
# Out:
# Top 10 Countries with the Highest 1-Week Change:
#           Country  1 week change
# 173            US         455582
# 79          India         324735
# 23         Brazil         323729
# 154  South Africa          78901
# 37       Colombia          53096
# 111        Mexico          46093
# 138        Russia          40468
# 6       Argentina          36642
# 132          Peru          32036
# 13     Bangladesh          18772

# %% [markdown]
# The top 3 countries are the US, India, and Brazil.

# %%
# Data from your DataFrame
c = mydataframe1['Country']
d100 = mydataframe1['Deaths / 100 Cases']

# Create bar plot
plt.figure(figsize=(32, 8))
plt.bar(c, d100, color='orange')
plt.xticks(rotation=90)
plt.title("Deaths by 100 Cases Across Countries")
plt.xlabel("Country")
plt.ylabel("Deaths by 100 Cases")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Few countries stand out due to their extremely high death rates and among them, the highest three are Yemen, the UK, and Belgium which can be due to many reasons like due to hospital capacity, age distribution, government response, etc.

# %%
# Line Plot for Weekly Change
plt.figure(figsize=(32, 6))
sns.lineplot(data=mydataframe1, x='Country', y='Deaths / 100 Recovered', marker='o', color='orange')
plt.xticks(rotation=90)
plt.title("Weekly Change in Confirmed Cases Over Countries")
plt.xlabel("Country")
plt.ylabel("Weekly Change")
plt.grid()
plt.show()

# %% [markdown]
# We have found out that the Netherlands and the UK have peaks in this plot, which means that the number of deaths per 100 recovered cases is increasing over time which can mean that country's situation is worsening. From the previous plot, we found out that the UK had high death rates.  So when compared to other countries UK was in a bad spot but this may need additional analysis with data which is related to the quality of healthcare, etc.

# %% [markdown]
# # Analysis for Dataset 2

# %%
# Histogram for GDP distribution in 2023
plt.figure(figsize=(12, 6))
sns.histplot(mydataframe2['2023'], bins=20, kde=True, color='blue')
plt.title('Histogram of GDP Distribution in 2023', fontsize=16)
plt.xlabel('GDP (Current US$)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid()
plt.show()

# %%
df2 = mydataframe2[['CountryName', '2020']].sort_values(by='2020', ascending=False).head(10)

# Create the bar plot using the function
create_barplot(df2, '2020', 'CountryName', 'Top 10 Countries by GDP in 2020',
               'Country', 'GDP (Current US$)', top_n=10)

# %%
df2 = mydataframe2[['CountryName', '2023']]

# Create the bar plot using the custom style function
create_barplot(df2, '2023', 'CountryName', 'Top 10 Countries by GDP in 2023',
                            'Country', 'GDP (Current US$)', top_n=10)

# %% [markdown]
# According to the bar graphs, the top three countries are World(of course), High Income, and OECD members which is the same across both of the graphs. The difference comes from the 10th position as in 2020 the place is held by the Upper middle-income group and in 2023 this place belongs to North America. Also when we compare the graphs, the GDP increased from 2020 to 2023.

# %%
plt.figure(figsize=(12, 6))
plt.scatter(mydataframe2['2020'], mydataframe2['2023'], alpha=0.7, color='purple')
plt.title('GDP in 2023 vs. GDP in 2020', fontsize=16)
plt.xlabel('GDP in 2020 (Current US$)', fontsize=14)
plt.ylabel('GDP in 2023 (Current US$)', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# In conclusion, in our EDA we plot the GDP in 2023 as against the GDP in 2020 at a scatter plot for different countries. A point on the plot corresponds to the country, its coordinates being the GDP in 2020 on the abscissa and the GDP in 2023 on the ordinate. We find a positive association this implies that the countries with above-average GDP in 2020 have relatively high GDP in 2023.

# %% [markdown]
# # Analysis for Dataset 3

# %%
cleaned_data = pd.read_csv('covid_19_clean_complete.csv', parse_dates=['Date'])
cleaned_data.head()
# Out:
#   Province/State Country/Region       Lat       Long       Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953 2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300 2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600 2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800 2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900 2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
# cases
cases = ['Confirmed', 'Deaths', 'Recovered', 'Active']

# Active Case = confirmed - deaths - recovered
cleaned_data['Active'] = cleaned_data['Confirmed'] - cleaned_data['Deaths'] - cleaned_data['Recovered']

# filling missing values
cleaned_data[['Province/State']] = cleaned_data[['Province/State']].fillna('')
cleaned_data[cases] = cleaned_data[cases].fillna(0)

cleaned_data.head()
# Out:
#   Province/State Country/Region       Lat       Long       Date  Confirmed  \
# 0                   Afghanistan  33.93911  67.709953 2020-01-22          0
# 1                       Albania  41.15330  20.168300 2020-01-22          0
# 2                       Algeria  28.03390   1.659600 2020-01-22          0
# 3                       Andorra  42.50630   1.521800 2020-01-22          0
# 4                        Angola -11.20270  17.873900 2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
# Creating the DataFrames with total cases for every country
confirmed_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Confirmed'].sum())
confirmed_cases['Country/Region'] = confirmed_cases.index
confirmed_cases.index = np.arange(1, len(confirmed_cases) + 1)

death_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Deaths'].sum())
death_cases['Country/Region'] = death_cases.index
death_cases.index = np.arange(1, len(death_cases) + 1)

recovered_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Recovered'].sum())
recovered_cases['Country/Region'] = recovered_cases.index
recovered_cases.index = np.arange(1, len(recovered_cases) + 1)

active_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Active'].sum())
active_cases['Country/Region'] = active_cases.index
active_cases.index = np.arange(1, len(active_cases) + 1)

# Select relevant columns for each case
global_active_cases = active_cases[['Country/Region', 'Active']]
global_death_cases = death_cases[['Country/Region', 'Deaths']]
global_recovered_cases = recovered_cases[['Country/Region', 'Recovered']]
global_confirmed_cases = confirmed_cases[['Country/Region', 'Confirmed']]

# Create barplots for each category using the function

# For Confirmed Cases
create_barplot(global_confirmed_cases, 'Confirmed', 'Country/Region', 'Confirmed Cases Worldwide',
               'Confirmed Cases', 'Country/Region')

# For Death Cases
create_barplot(global_death_cases, 'Deaths', 'Country/Region', 'Death Cases Worldwide',
               'Deaths', 'Country/Region')

# For Recovered Cases
create_barplot(global_recovered_cases, 'Recovered', 'Country/Region', 'Recovered Cases Worldwide',
               'Recovered Cases', 'Country/Region')

# For Active Cases
create_barplot(global_active_cases, 'Active', 'Country/Region', 'Active Cases Worldwide',
               'Active Cases', 'Country/Region')

# %% [markdown]
# - The US has the highest number of confirmed cases, deaths, recoveries, and active cases. After the COVID-19 pandemic, the US has managed to care for those affected and now has the most active cases.
# - followed by Brazil ,United Kingdom , and Russia in top 3 places and then the rest of the Countries
# - so lets make visualizations accordingly to the above result

# %%
# Grouping by 'Date' and selecting the desired columns as a list
date_c = cleaned_data.groupby('Date')[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum().reset_index()

# Set the figure and axes for the subplots
fig, axes = plt.subplots(1, 4, figsize=(20, 6), sharex=True)

# Plot for Confirmed cases
sns.lineplot(x='Date', y='Confirmed', data=date_c, ax=axes[0], color='orange', marker='o')
axes[0].set_title("Confirmed")
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Confirmed Cases')
axes[0].tick_params(axis='x', rotation=45)

# Plot for Death cases
sns.lineplot(x='Date', y='Deaths', data=date_c, ax=axes[1], color='red', marker='o')
axes[1].set_title("Deaths")
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Deaths')
axes[1].tick_params(axis='x', rotation=45)

# Plot for Recovered cases
sns.lineplot(x='Date', y='Recovered', data=date_c, ax=axes[2], color='green', marker='o')
axes[2].set_title("Recovered")
axes[2].set_xlabel('Date')
axes[2].set_ylabel('Recovered')
axes[2].tick_params(axis='x', rotation=45)

# Plot for Active cases
sns.lineplot(x='Date', y='Active', data=date_c, ax=axes[3], color='blue', marker='o')
axes[3].set_title("Active")
axes[3].set_xlabel('Date')
axes[3].set_ylabel('Active Cases')
axes[3].tick_params(axis='x', rotation=45)

# Set a global title for the entire plot
fig.suptitle('Global Spread of the Coronavirus Over Time', fontsize=16, fontweight='bold')

# Adjust the layout to ensure there's no overlap
plt.tight_layout()
plt.subplots_adjust(top=0.85)  # Adjust the top to make room for the global title

# Show the plot
plt.show()

# %% [markdown]
# - The adove is visual is the Global Spread of the COVID-19 in all over time
# - The Comfirmed cases are more than 15000K and Deaths is more than 600K
# - The Recovered is more tha 100K and the active is nearly 8000k

# %%
cleaned_latest = cleaned_data[cleaned_data['Date'] == max(cleaned_data['Date'])]
flg = cleaned_latest.groupby('Country/Region')[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum().reset_index()

flg['mortalityRate'] = round((flg['Deaths'] / flg['Confirmed']) * 100, 2)

# Filter data where 'Confirmed' > 100 and sort by 'mortalityRate'
temp = flg[flg['Confirmed'] > 100]
temp = temp.sort_values('mortalityRate', ascending=False)

# Set the plot size
plt.figure(figsize=(10, 6))

# Create a horizontal bar plot with Seaborn, assigning 'mortalityRate' to 'hue'
sns.barplot(
    x='mortalityRate',
    y='Country/Region',
    data=temp.sort_values(by="mortalityRate", ascending=False)[:10][::-1],
    hue='Country/Region',  # Adding hue here
    dodge=False  # Removes legend and color variation for each country
)

# Set plot title and labels
plt.title('Deaths per 100 Confirmed Cases', fontsize=16, fontweight='bold')
plt.xlabel('Mortality Rate (%)')
plt.ylabel('Country/Region')

# Display the plot
plt.show()

# %% [markdown]
# Yemen had most mortality rates

# %% [markdown]
# # Extra

# %%
# Scatter Plot for 1-Week Change vs. 1-Week Percentage Increase
plt.figure(figsize=(10, 6))
plt.scatter(mydataframe1['1 week change'], mydataframe1['1 week % increase'], color='blue', alpha=0.6, edgecolors='w', s=40)
plt.title("1-Week Change vs. 1-Week Percentage Increase")
plt.xlabel("1-Week Change")
plt.ylabel("1-Week Percentage Increase")
plt.grid()
plt.show()

# %%
# Line Plot for Weekly Change
plt.figure(figsize=(32, 6))
sns.lineplot(data=mydataframe1, x='Country', y='Recovered / 100 Cases', marker='o', color='orange')
plt.xticks(rotation=90)
plt.title("Weekly Change in Confirmed Cases Over Countries")
plt.xlabel("Country")
plt.ylabel("Weekly Change")
plt.grid()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, while we are aware of the unprecedented impact COVID-19 had worldwide, examining the data brings a deeper understanding of its rapid spread and severity. The dramatic weekly change in cases, reaching up to 226% in some regions, highlights how quickly the virus permeated communities and underscores the urgent need for responsive health systems. Beyond case counts, the economic data also reflects a complex reality: despite the pandemic’s challenges, stimulus measures, shifts in consumer behavior, and adaptive industries contributed to a surprising GDP growth in many countries. One of the important observations we made is that the UK struggled more than some of the other countries like the US which resulted in more deaths and there also could be other reasons but these datasets reached their limit to understand this pattern better. This data-driven perspective reinforces the magnitude of the pandemic’s effects on both public health and the global economy, illustrating just how resilient yet vulnerable our interconnected world can be.
